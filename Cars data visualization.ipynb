# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %matplotlib inline

# %%
#https://rpubs.com/tautiss/872905

# %% [markdown]
# ### Data Import

# %%
cars_df=pd.read_csv("cars_df.csv")

# %%
cars_df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # The following topics are covered in this tutorial:
#
# - Selecting and downloading a dataset
# - Data preparation and cleaning
# - Exploratory analysis and visualization
# - Asking and answering interesting questions
# - Summarizing inferences and drawing conclusions

# %% [markdown]
# # Exploretory Analysis and Visualation

# %% [markdown]
#  ### Quation:1 Tops 10 biggest compey made car MANUFACTURER ?

# %%
top_10_brands=cars_df.Make.value_counts().head(10)

# %%
#visualization by metplotlib: 
top_10_brands.plot(kind='bar');

plt.xlabel('Barnds')
plt.ylabel("count")
plt.title('Top 10 Biggest Car Manufacturer');

# %%
#visualization by seaborn:

sns.barplot(x=top_10_brands.index,y=top_10_brands)
plt.xticks(rotation=90);



plt.xlabel('Barnds')
plt.ylabel("count")
plt.title('Top 10 Biggest Car Manufacturer');

# %% [markdown]
# ### Q2.Draw a PieChat on The Bassis of Vehicle Style?

# %%
car_size = cars_df["Vehicle Size"].value_counts()
car_size
# Out:
# Compact    4764
# Midsize    4373
# Large      2777
# Name: Vehicle Size, dtype: int64

# %%
plt.figure(figsize=(12,4))
plt.title("Vehicle Size")
plt.pie(car_size, labels=car_size.index, autopct='%1.f%%', startangle=180);

# %% [markdown]
# ### Q2.Draw a PieChat on The Bassis of Vehicle Size ?

# %%
car_Transmission_Type= cars_df["Transmission Type"].value_counts()
car_Transmission_Type
# Out:
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: Transmission Type, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title("Transmission Type")
plt.pie(car_Transmission_Type, labels=car_Transmission_Type.index, autopct='%1.f%%', startangle=180);

# %% [markdown]
# ### Q3. How many cars sales in each year ?

# %%
car_sales=cars_df.groupby("Year").Popularity.sum()
car_sales
# Out:
# Year
# 1990     179094
# 1991     221554
# 1992     245669
# 1993     267801
# 1994     206692
# 1995     234082
# 1996     246158
# 1997     339845
# 1998     284589
# 1999     190365
# 2000     124745
# 2001     202415
# 2002     290977
# 2003     332013
# 2004     319835
# 2005     276366
# 2006     249107
# 2007     404220
# 2008     473713
# 2009     563883
# 2010     388318
# 2011     314240
# 2012     384171
# 2013     461542
# 2014     780564
# 2015    3678252
# 2016    3705127
# 2017    3159875
# Name: Popularity, dtype: int64

# %%
sns.barplot(x=car_sales.index,y=car_sales)
plt.xticks(rotation=90)
plt.xlabel("Year")
plt.ylabel('price');

# %% [markdown]
# ### Q4.Plotting the data according to the price based on engine size?

# %%
  


plt.scatter(cars_df['Engine HP'], cars_df['MSRP'])
plt.title('Scatterplot of Enginesize vs Price')
plt.xlabel('Engine size')
plt.ylabel('Price')

plt.show()

# %%
# in dataset remove null value frist of all:

# %%
cars_df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
cars_df.drop("Market Category" ,axis=1)
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ## Q5) in datafream all null values remove and fill mean value ?

# %%
cars_df['Make'].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
cars_df["Engine HP"].fillna(cars_df["Engine HP"].mean(),inplace=True)

# %%
cars_df["Engine Cylinders"].fillna(cars_df["Engine Cylinders"],inplace=True)

# %%
cars_df1=cars_df.drop(["Market Category"],axis=1)

# %%
cars_df1.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     3
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      6
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# # Q6) show data only Engine HP above 300hp?

# %%
cars_df1[cars_df1["Engine HP"]> 300]
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 15     BMW    1 Series  2013  premium unleaded (required)      320.0
# 16     BMW    1 Series  2013  premium unleaded (required)      320.0
# 43     BMW    2 Series  2016  premium unleaded (required)      320.0
# 46     BMW    2 Series  2016  premium unleaded (required)      320.0
# ...    ...         ...   ...                          ...        ...
# 11899  BMW          Z4  2015  premium unleaded (required)      335.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# ## Q7)show data only MPR above 40000$?

# %%
cars_df1[cars_df1["MSRP"]> 40000 ]
# Out:
#         Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0        BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1        BMW    1 Series  2011     premium unleaded (required)      300.0
# 6        BMW    1 Series  2012     premium unleaded (required)      300.0
# 12       BMW    1 Series  2013     premium unleaded (required)      300.0
# 15       BMW    1 Series  2013     premium unleaded (required)      320.0
# ...      ...         ...   ...                             ...        ...
# 11908  Acura         ZDX  2011     premium unleaded (required)      300.0
# 11909  Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910  Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911  Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912  Acura         ZDX  2013  premium unleaded (recommended)      300.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# # Q7) increase all  the value of "mpg" column by 3 ?

# %%
cars_df1["highway MPG"]= cars_df1["highway MPG"].apply(lambda x:x+3)

# %%
cars_df1
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# #   Q8) groupby model year with MPR.

# %%
cars_df1.groupby("Year")["MSRP"].mean().plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ## Q9) Show all the records where "Vehicle Style" is coupe and convetable .

# %%
cars_df1[cars_df1["Vehicle Style"].isin(["coupe","Convertible"])]
# Out:
#       Make     Model  Year             Engine Fuel Type  Engine HP  \
# 1      BMW  1 Series  2011  premium unleaded (required)      300.0
# 4      BMW  1 Series  2011  premium unleaded (required)      230.0
# 6      BMW  1 Series  2012  premium unleaded (required)      300.0
# 8      BMW  1 Series  2012  premium unleaded (required)      230.0
# 9      BMW  1 Series  2013  premium unleaded (required)      230.0
# ...    ...       ...   ...                          ...        ...
# 11901  BMW        Z4  2016  premium unleaded (required)      240.0
# 11902  BMW        Z4  2016  premium unleaded (required)      335.0
# 11903  BMW        Z8  2001  premium unleaded (required)      394.0
# 11904  BMW        Z8  2002  premium unleaded (required)      394.0
# 11905  BMW        Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 1                   6.0            MANUAL  rear wheel drive              2.0
# ...

# %% [markdown]
# ## Q10) comparing BMW And Mercedes-Benz with price.

# %%
data_annova = cars_df1[['Make', 'MSRP']]
grouped_annova = data_annova.groupby(['Make'])
annova_results_l = sp.stats.f_oneway(
                             grouped_annova.get_group('BMW')['MSRP'],
                             grouped_annova.get_group('Mercedes-Benz')['MSRP']
                                    )
#print(annova_results_l)
  

sns.regplot(x ='Engine Cylinders', y ='MSRP', data = cars_df1)
plt.ylim(0, )
# Out:
# (0.0, 2172740.3138424866)
